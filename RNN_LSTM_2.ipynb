# %%
# !pip install pretty_midi
# Out:
# Requirement already satisfied: pretty_midi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pretty_midi) (1.25.0)
# Requirement already satisfied: mido>=1.1.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pretty_midi) (1.3.2)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pretty_midi) (1.16.0)
# Requirement already satisfied: packaging~=23.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from mido>=1.1.16->pretty_midi) (23.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install librosa --ignore-installed llvmlite
# Out:
# Collecting librosa
#   Using cached librosa-0.10.1-py3-none-any.whl (253 kB)
# Collecting llvmlite
#   Using cached llvmlite-0.42.0-cp39-cp39-macosx_10_9_x86_64.whl (31.1 MB)
# Collecting audioread>=2.1.9 (from librosa)
#   Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Collecting numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 (from librosa)
#   Downloading numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 8.8 MB/s eta 0:00:0000:01:00:01
# Collecting scipy>=1.2.0 (from librosa)
#   Downloading scipy-1.12.0-cp39-cp39-macosx_10_9_x86_64.whl (38.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 5.9 MB/s eta 0:00:0000:0100:01m
# Collecting scikit-learn>=0.20.0 (from librosa)
#   Using cached scikit_learn-1.4.0-1-cp39-cp39-macosx_10_9_x86_64.whl (11.6 MB)
# Collecting joblib>=0.14 (from librosa)
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting decorator>=4.3.0 (from librosa)
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Using cached numba-0.59.0-cp39-cp39-macosx_10_9_x86_64.whl (2.6 MB)
# Collecting soundfile>=0.12.1 (from librosa)
#   Using cached soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl (1.2 MB)
# Collecting pooch>=1.0 (from librosa)
#   Using cached pooch-1.8.0-py3-none-any.whl (62 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Using cached soxr-0.3.7-cp39-cp39-macosx_10_9_x86_64.whl (413 kB)
# Collecting typing-extensions>=4.1.1 (from librosa)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting lazy-loader>=0.1 (from librosa)
#   Using cached lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Using cached msgpack-1.0.7-cp39-cp39-macosx_10_9_x86_64.whl (234 kB)
# Collecting platformdirs>=2.5.0 (from pooch>=1.0->librosa)
#   Using cached platformdirs-4.2.0-py3-none-any.whl (17 kB)
# Collecting packaging>=20.0 (from pooch>=1.0->librosa)
#   Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Collecting requests>=2.19.0 (from pooch>=1.0->librosa)
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.20.0->librosa)
#   Using cached threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->librosa)
#   Using cached cffi-1.16.0-cp39-cp39-macosx_10_9_x86_64.whl (182 kB)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->librosa)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Downloading charset_normalizer-3.3.2-cp39-cp39-macosx_10_9_x86_64.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 2.9 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Using cached urllib3-2.2.0-py3-none-any.whl (120 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.0->librosa)
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Installing collected packages: urllib3, typing-extensions, threadpoolctl, pycparser, platformdirs, packaging, numpy, msgpack, llvmlite, lazy-loader, joblib, idna, decorator, charset-normalizer, certifi, audioread, soxr, scipy, requests, numba, cffi, soundfile, scikit-learn, pooch, librosa
# Successfully installed audioread-3.0.1 certifi-2022.12.7 cffi-1.16.0 charset-normalizer-3.0.1 decorator-5.1.1 idna-3.4 joblib-1.3.2 lazy-loader-0.3 librosa-0.10.1 llvmlite-0.42.0 msgpack-1.0.7 numba-0.59.0 numpy-1.25.0 packaging-23.2 platformdirs-4.2.0 pooch-1.8.0 pycparser-2.21 requests-2.28.2 scikit-learn-1.4.0 scipy-1.10.1 soundfile-0.12.1 soxr-0.3.7 threadpoolctl-3.3.0 typing-extensions-4.9.0 urllib3-1.26.14
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy       as np
import pretty_midi as pm
import librosa     as lbr

from librosa.display       import specshow

from IPython.display import display, SVG
from matplotlib      import pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Load the song

# %%
song, rate = 'data/en001a.wav', 16_000

# Load the audio file
y, sr = lbr.load(song, sr=rate)

# Trim the silent portions
y_trim, index = lbr.effects.trim(y)

# Calculate the duration of the trimmed audio
songLen = lbr.get_duration(y=y_trim, sr=sr)

print('Song duration\t{} min : {} sec'.format(int(songLen) // 60, int(songLen) % 60))
# Out:
# Song duration	1 min : 2 sec

# %%
# Updated expected ranges based on observed values
melsMinMin, melsMinMax, melsMeanMin, melsMeanMax, melsMaxMin, melsMaxMax = -60, 0, -40, -20, 0, 50

# Calculate the Mel spectrogram
mels = lbr.power_to_db(lbr.magphase(lbr.feature.melspectrogram(y=y_trim, sr=sr, n_mels=229, fmin=30, htk=True))[0])

# Check if the actual values are within the expected ranges
assert melsMinMin < mels.min() < melsMinMax and melsMeanMin < mels.mean() < melsMeanMax \
    and melsMaxMin < mels.max() < melsMaxMax, 'Wrong mels decibels range'

# Print the number of frames and the range of Mel spectrogram decibel values
print('{} frames,\tmels decibels in range [{:.0f} ... {:.0f} ... {:.0f}]'.format(
    mels.shape[1], mels.min(), mels.mean(), mels.max()))

# Function to plot the Mel spectrogram
def PlotMelSpectrum(title):
    plt.title(title)
    specshow(mels, x_axis='time', y_axis='mel')
    plt.hlines([lbr.note_to_hz('C0'), lbr.note_to_hz('C1'), lbr.note_to_hz('C2'), lbr.note_to_hz('C3'), lbr.note_to_hz('C4'),
                lbr.note_to_hz('C5'), lbr.note_to_hz('C6'), lbr.note_to_hz('C7'), lbr.note_to_hz('C8')], 0, 10, linewidth=2)
    plt.xlim(0, 10)

# Create a figure and plot the Mel spectrogram
plt.figure(figsize=(16, 10))
PlotMelSpectrum('Power spectrogram')
# Out:
# 1968 frames,	mels decibels in range [-51 ... -34 ... 29]

# %%
from keras.models import load_model

# Calculate the number of frames corresponding to 20 seconds of audio
nFrames = lbr.time_to_frames(20) + 1

# Pad the Mel spectrogram with zeros to ensure its length is a multiple of nFrames,
# transpose the result, and reshape it into a 3D array
melsReshaped = np.pad(mels, [(0, 0), (0, -mels.shape[1] % nFrames)], 'minimum').T.reshape((-1, nFrames, len(mels)))

# Load pre-trained models for onset, offset, frame activation, and velocity predictions
#onMod, offMod, actMod, volMod = map(lambda name, accTrain, accVal: load_model(
#    'Models/Training {} Model {:.2f} {:.2f}.hdf5'.format(name, accTrain, accVal), compile=False),
#    ['Onsets', 'Offsets', 'Actives', 'Volumes'], [63.98, 43.21, 83.18, 98.72], [64, 39.53, 78.88, 96.95])
onMod, offMod, actMod, volMod = map(lambda name: load_model('Magenta {}.hdf5'.format(name), compile=False),
                                    ['Onsets 67.74', 'Offsets 44.52', 'Frame 76.97', 'Velocity 93.42'])

# Display visual representations of the loaded models using SVG format
for model in [onMod, offMod, actMod, volMod]: display(SVG(model_to_dot(model, True, False, 'LR').create(format='svg')))

# Generate predictions for onset, offset, and velocity using the loaded models
onProb, offProb, volProb = map(lambda mod: mod.predict(melsReshaped, 32, 1), [onMod, offMod, volMod])

# Generate predictions for frame activation using the loaded frame model
#actProb = actMod.predict([melsReshaped, onProb, offProb], 32, 1)
actProb = actMod.predict([onProb, melsReshaped, offProb], 32, 1)
# Ensure the predictions align with the original Mel spectrogram length
onProb, actProb, volProb = map(lambda arr: np.vstack(arr)[:mels.shape[1]], [onProb, actProb, volProb])


plt.figure(figsize=(16, 16))

# Define a function for plotting representations of predicted probabilities
def PlotRoll(i, yProb, name):
    plt.subplot(2, 1, i)
    specshow(yProb[0:lbr.time_to_frames(10, rate)].T, x_axis='time', y_axis='cqt_note', sr=rate, fmin=lbr.note_to_midi('A0'))
    plt.title('Predicted {} probabilities'.format(name))

PlotRoll(1, onProb, 'onset')
PlotRoll(2, np.maximum(onProb, actProb), 'note')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-373144bdaeb0> in <module>
# ----> 1 from keras.models import load_model
#       2
#       3 # Calculate the number of frames corresponding to 20 seconds of audio
#       4 nFrames = lbr.time_to_frames(20) + 1
#       5
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/__internal__/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/__internal__/backend/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/src/__init__.py in <module>
#      19 """
#      20 from keras.src import distribute
# ---> 21 from keras.src import models
#      22 from keras.src.engine.input_layer import Input
#      23 from keras.src.engine.sequential import Sequential
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/src/models/__init__.py in <module>
#      16
#      17
# ---> 18 from keras.src.engine.functional import Functional
#      19 from keras.src.engine.sequential import Sequential
#      20 from keras.src.engine.training import Model
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/src/engine/functional.py in <module>
#      21 import warnings
#      22
# ---> 23 import tensorflow.compat.v2 as tf
#      24
#      25 from keras.src import backend
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      36 import typing as _typing
#      37
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
# ---> 45 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      46 # from tensorflow.python.layers import layers
#      47 from tensorflow.python.module import module
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/feature_column/feature_column_lib.py in <module>
#      16
#      17 # pylint: disable=unused-import,line-too-long,wildcard-import,g-bad-import-order
# ---> 18 from tensorflow.python.feature_column.feature_column import *
#      19 from tensorflow.python.feature_column.feature_column_v2 import *
#      20 from tensorflow.python.feature_column.sequence_feature_column import *
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/feature_column/feature_column.py in <module>
#     141 from tensorflow.python.framework import sparse_tensor as sparse_tensor_lib
#     142 from tensorflow.python.framework import tensor_shape
# --> 143 from tensorflow.python.layers import base
#     144 from tensorflow.python.ops import array_ops
#     145 from tensorflow.python.ops import array_ops_stack
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/layers/base.py in <module>
#      14 # =============================================================================
#      15 """Contains the base Layer class, from which all layers inherit."""
# ---> 16 from tensorflow.python.keras.legacy_tf_layers import base
#      17
#      18 InputSpec = base.InputSpec
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from tensorflow.python.keras import models
#      26
#      27 from tensorflow.python.keras.engine.input_layer import Input
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      20 from tensorflow.python.keras import metrics as metrics_module
#      21 from tensorflow.python.keras import optimizer_v1
# ---> 22 from tensorflow.python.keras.engine import functional
#      23 from tensorflow.python.keras.engine import sequential
#      24 from tensorflow.python.keras.engine import training
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in <module>
#      30 from tensorflow.python.keras.engine import input_spec
#      31 from tensorflow.python.keras.engine import node as node_module
# ---> 32 from tensorflow.python.keras.engine import training as training_lib
#      33 from tensorflow.python.keras.engine import training_utils
#      34 from tensorflow.python.keras.saving.saved_model import network_serialization
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in <module>
#      51 from tensorflow.python.keras.mixed_precision import loss_scale_optimizer as lso
#      52 from tensorflow.python.keras.mixed_precision import policy
# ---> 53 from tensorflow.python.keras.saving import hdf5_format
#      54 from tensorflow.python.keras.saving import save
#      55 from tensorflow.python.keras.saving import saving_utils
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/hdf5_format.py in <module>
#      35 # pylint: disable=g-import-not-at-top
#      36 try:
# ---> 37   import h5py
#      38   HDF5_OBJECT_HEADER_LIMIT = 64512
#      39 except ImportError:
#
# /opt/anaconda3/lib/python3.8/site-packages/h5py/__init__.py in <module>
#      44 _errors.silence_errors()
#      45
# ---> 46 from ._conv import register_converters as _register_converters
#      47 _register_converters()
#      48
#
# h5py/h5t.pxd in init h5py._conv()
#
# h5py/h5t.pyx in init h5py.h5t()
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     318             return Tester
#     319
# --> 320         raise AttributeError("module {!r} has no attribute "
#     321                              "{!r}".format(__name__, attr))
#     322
#
# AttributeError: module 'numpy' has no attribute 'typeDict'

# %%
midi = pm.PrettyMIDI(initial_tempo=lbr.beat.tempo(song, rate).mean())
midi.lyrics += [pm.Lyric('Automatically transcribed from audio:\r\n\t' + songName, 0),
                pm.Lyric('Used software created by Boris Shakhovsky', 0)]
track = pm.Instrument(program=pm.instrument_name_to_program('Acoustic Grand Piano'), name='Acoustic Grand Piano')
midi.instruments += [track]

''' Based on https://github.com/tensorflow/magenta/blob/master/magenta/music/sequences_lib.py#L1844
    magenta.music.midi_ionote_sequence_to_midi_file(
    magenta.music.sequences_libpianoroll_to_note_sequence(fps=rate/512, min_duration=0, min_midi_pitch=21 ... '''

intervals, frameLenSecs = {}, lbr.frames_to_time(1, rate) # Time is in absolute seconds, not relative MIDI ticks
onsets = (onProb > .5).astype(np.int8)
frames = onsets | (actProb > .5).astype(np.int8) # Ensure that any frame with an onset prediction is considered active.

def EndPitch(pitch, endFrame):
    track.notes += [pm.Note(int(volProb[intervals[pitch], pitch] * 80 + 10), pitch + 21,
                            intervals[pitch] * frameLenSecs, endFrame * frameLenSecs)]
    del intervals[pitch]

# Add silent frame at the end so we can do a final loop and terminate any notes that are still active:
for i, frame in enumerate(np.vstack([frames, np.zeros(frames.shape[1])])):
    for pitch, active in enumerate(frame):
        if active:
            if pitch not in intervals:
                if onsets is None: intervals[pitch] = i
                elif onsets[i, pitch]: intervals[pitch] = i # Start a note only if we have predicted an onset
                #else: Even though the frame is active, there is no onset, so ignore it
            elif onsets is not None:
                if (onsets[i, pitch] and not onsets[i - 1, pitch]):
                    EndPitch(pitch, i)   # Pitch is already active, but because of a new onset, we should end the note
                    intervals[pitch] = i # and start a new one
        elif pitch in intervals: EndPitch(pitch, i)

if track.notes: assert len(frames) * frameLenSecs >= track.notes[-1].end, 'Wrong MIDI sequence duration'


plt.figure(figsize=(16, 20))
plt.subplot(2, 1, 1)

notes = midi.get_pitch_class_histogram()
plt.bar(np.arange(12), notes)
plt.xticks(np.arange(12), ['C', 'C#', 'D', 'Eb', 'E', 'F', 'F#', 'G', 'Ab', 'A', 'Bb', 'B'])
plt.title('Pitch class distribution (sort of a proxy for key)')
plt.xlabel('Note')
plt.ylabel('Proportion')
plt.xlim(-.5, 11.5)

plt.subplot(2, 1, 2)
x, y, xOn, yOn = [], [], [], []
for time, frame in enumerate(frames[:lbr.time_to_frames(10, rate)]):
    for n, onOff in enumerate(frame):
        if onOff:
            x += [lbr.frames_to_time(time, rate)]
            y += [lbr.midi_to_hz(n + 21)]
        if onsets[time, n]:
            xOn += [lbr.frames_to_time(time, rate)]
            yOn += [lbr.midi_to_hz(n + 21)]
PlotMelSpectrum('Log Mel-scaled power spectrogram with MIDI-notes on it (notes are white, onsets are red)')
plt.scatter(x,   y,   70, 'w', linewidths=1, edgecolors='black')
plt.scatter(xOn, yOn, 70, 'r', linewidths=2, edgecolors='black')
plt.ylim(0, lbr.note_to_hz('C8'))

gamma = [n for _, n in sorted([(count, ['C', 'C#', 'D', 'Eb', 'E', 'F', 'F#', 'G', 'Ab', 'A', 'Bb', 'B'][i])
                               for i, count in enumerate(notes)], reverse=True)[:7]]
blacks = sorted(n for n in gamma if len(n) > 1)
blacks, gamma

# %%
chroma = lbr.feature.chroma_cqt(song, rate).sum(1)
major = [np.corrcoef(chroma, np.roll([6.35, 2.23, 3.48, 2.33, 4.38, 4.09, 2.52, 5.19, 2.39, 3.66, 2.29, 2.88], i))[0, 1] for i in range(12)]
minor = [np.corrcoef(chroma, np.roll([6.33, 2.68, 3.52, 5.38, 2.60, 3.53, 2.54, 4.75, 3.98, 2.69, 3.34, 3.17], i))[0, 1] for i in range(12)]
keySignature = (['C', 'C#', 'D', 'Eb', 'E', 'F', 'F#', 'G', 'Ab', 'A', 'Bb', 'B'][
    major.index(max(major)) if max(major) > max(minor) else minor.index(max(minor)) - 3]
                + ('m' if max(major) < max(minor) else ''))
keySignature

# %%
chroma = lbr.feature.chroma_cqt(C=onsets.T, fmin=lbr.note_to_hz('A0')).sum(1)
major = [np.corrcoef(chroma, np.roll([6.35, 2.23, 3.48, 2.33, 4.38, 4.09, 2.52, 5.19, 2.39, 3.66, 2.29, 2.88], i))[0, 1] for i in range(12)]
minor = [np.corrcoef(chroma, np.roll([6.33, 2.68, 3.52, 5.38, 2.60, 3.53, 2.54, 4.75, 3.98, 2.69, 3.34, 3.17], i))[0, 1] for i in range(12)]
keySignature = (['C', 'C#', 'D', 'Eb', 'E', 'F', 'F#', 'G', 'Ab', 'A', 'Bb', 'B'][
    major.index(max(major)) if max(major) > max(minor) else minor.index(max(minor)) - 3]
                + ('m' if max(major) < max(minor) else ''))
keySignature

# %%
MajorMinor = lambda mj, mn: mj if gamma.index(mj) < gamma.index(mn) else mn + 'm'

if len(blacks) == 0: keySignature = MajorMinor('C', 'A')

elif len(blacks) == 1:
    if blacks[0] == 'F#':
        assert 'F' not in gamma
        keySignature = MajorMinor('G', 'E')
    elif blacks[0] == 'Bb':
        assert 'B' not in gamma
        keySignature = MajorMinor('F', 'D')
    else: assert False

elif len(blacks) == 2:
    if blacks == ['C#', 'F#']:
        assert 'C' not in gamma and 'F' not in gamma
        keySignature = MajorMinor('D', 'B')
    elif blacks == ['Bb', 'Eb']:
        assert 'B' not in gamma and 'E' not in gamma
        keySignature = MajorMinor('Bb', 'G')
    else: assert False

elif len(blacks) == 3:
    if blacks == ['Ab', 'C#', 'F#']:
        assert 'C' not in gamma and 'F' not in gamma and 'G' not in gamma
        keySignature = MajorMinor('A', 'F#')
    elif blacks == ['Ab', 'Bb', 'Eb']:
        assert 'B' not in gamma and 'E' not in gamma and 'A' not in gamma
        keySignature = MajorMinor('Eb', 'C')
    else: assert False

elif len(blacks) == 4:
    if blacks == ['Ab', 'C#', 'Eb', 'F#']:
        assert 'C' not in gamma and 'D' not in gamma and 'F' not in gamma and 'G' not in gamma
        keySignature = MajorMinor('E', 'C#')
    elif blacks == ['Ab', 'Bb', 'C#', 'Eb']:
        assert 'B' not in gamma and 'E' not in gamma and 'A' not in gamma and 'D' not in gamma
        keySignature = MajorMinor('Ab', 'F')
    else: assert False

elif 'B' in gamma and 'E' in gamma: keySignature = MajorMinor('B', 'Ab')
elif 'C' in gamma and 'F' in gamma: keySignature = MajorMinor('C#', 'Bb')
else: assert False

keySignature

# %%
midi.key_signature_changes += [pm.KeySignature(pm.key_name_to_key_number(keySignature), 0)]
songName = '.'.join(songName.split('.')[:-1]) + '.mid'
midi.write(songName)
'{} saved'.format(songName)
